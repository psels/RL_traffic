# %%
import pandas as pd

# %%
dict = {'junction_1': {'all_phases': {"(Logic(programID='0', type=0, currentPhaseIndex=0, phases=(Phase(duration=35.0, state='GGGgrrrrGGGgrrrr', minDur=35.0, maxDur=35.0), Phase(duration=10.0, state='yyyyrrrryyyyrrrr', minDur=10.0, maxDur=10.0), Phase(duration=35.0, state='rrrrGGGgrrrrGGGg', minDur=35.0, maxDur=35.0), Phase(duration=10.0, state='rrrryyyyrrrryyyy', minDur=10.0, maxDur=10.0)), subParameter={}),)"}, 'current_phase': {0}, 'nb_lanes': 16, 'lanes_list': ('end_B_junction_1_0', 'end_B_junction_1_0', 'end_B_junction_1_1', 'end_B_junction_1_1', 'junction_2_junction_1_0', 'junction_2_junction_1_0', 'junction_2_junction_1_1', 'junction_2_junction_1_1', 'junction_6_junction_1_0', 'junction_6_junction_1_0', 'junction_6_junction_1_1', 'junction_6_junction_1_1', 'end_A_junction_1_0', 'end_A_junction_1_0', 'end_A_junction_1_1', 'end_A_junction_1_1'), 'lane_halting': {'end_B_junction_1_0': 0, 'end_B_junction_1_1': 0, 'junction_2_junction_1_0': 0, 'junction_2_junction_1_1': 0, 'junction_6_junction_1_0': 0, 'junction_6_junction_1_1': 0, 'end_A_junction_1_0': 0, 'end_A_junction_1_1': 0}, 'passenger_halting': {'end_B_junction_1_0': 0.0, 'end_B_junction_1_1': 0.0, 'junction_2_junction_1_0': 0.0, 'junction_2_junction_1_1': 0.0, 'junction_6_junction_1_0': 0.0, 'junction_6_junction_1_1': 0.0, 'end_A_junction_1_0': 0.0, 'end_A_junction_1_1': 0.0}, 'passenger_wait_time': {'end_B_junction_1_0': 0.0, 'end_B_junction_1_1': 0.0, 'junction_2_junction_1_0': 0.0, 'junction_2_junction_1_1': 0.0, 'junction_6_junction_1_0': 0.0, 'junction_6_junction_1_1': 0.0, 'end_A_junction_1_0': 0.0, 'end_A_junction_1_1': 0.0}, 'lane_occupency': {'end_B_junction_1_0': 0, 'end_B_junction_1_1': 3, 'junction_2_junction_1_0': 0, 'junction_2_junction_1_1': 0, 'junction_6_junction_1_0': 0, 'junction_6_junction_1_1': 0, 'end_A_junction_1_0': 3, 'end_A_junction_1_1': 0}, 'lane_speed': {'end_B_junction_1_0': 0.0, 'end_B_junction_1_1': 25.510708270095797, 'junction_2_junction_1_0': 0.0, 'junction_2_junction_1_1': 0.0, 'junction_6_junction_1_0': 0.0, 'junction_6_junction_1_1': 0.0, 'end_A_junction_1_0': 22.57750235386965, 'end_A_junction_1_1': 0.0}}, 'junction_2': {'all_phases': {"(Logic(programID='0', type=0, currentPhaseIndex=0, phases=(Phase(duration=35.0, state='GGGgrrrrGGGgrrrr', minDur=35.0, maxDur=35.0), Phase(duration=10.0, state='yyyyrrrryyyyrrrr', minDur=10.0, maxDur=10.0), Phase(duration=35.0, state='rrrrGGGgrrrrGGGg', minDur=35.0, maxDur=35.0), Phase(duration=10.0, state='rrrryyyyrrrryyyy', minDur=10.0, maxDur=10.0)), subParameter={}),)"}, 'current_phase': {0}, 'nb_lanes': 16, 'lanes_list': ('end_C_junction_2_0', 'end_C_junction_2_0', 'end_C_junction_2_1', 'end_C_junction_2_1', 'end_D_junction_2_0', 'end_D_junction_2_0', 'end_D_junction_2_1', 'end_D_junction_2_1', 'junction_3_junction_2_0', 'junction_3_junction_2_0', 'junction_3_junction_2_1', 'junction_3_junction_2_1', 'junction_1_junction_2_0', 'junction_1_junction_2_0', 'junction_1_junction_2_1', 'junction_1_junction_2_1'), 'lane_halting': {'end_C_junction_2_0': 0, 'end_C_junction_2_1': 0, 'end_D_junction_2_0': 0, 'end_D_junction_2_1': 0, 'junction_3_junction_2_0': 0, 'junction_3_junction_2_1': 0, 'junction_1_junction_2_0': 0, 'junction_1_junction_2_1': 0}, 'passenger_halting': {'end_C_junction_2_0': 0.0, 'end_C_junction_2_1': 0.0, 'end_D_junction_2_0': 0.0, 'end_D_junction_2_1': 0.0, 'junction_3_junction_2_0': 0.0, 'junction_3_junction_2_1': 0.0, 'junction_1_junction_2_0': 0.0, 'junction_1_junction_2_1': 0.0}, 'passenger_wait_time': {'end_C_junction_2_0': 0.0, 'end_C_junction_2_1': 0.0, 'end_D_junction_2_0': 0.0, 'end_D_junction_2_1': 0.0, 'junction_3_junction_2_0': 0.0, 'junction_3_junction_2_1': 0.0, 'junction_1_junction_2_0': 0.0, 'junction_1_junction_2_1': 0.0}, 'lane_occupency': {'end_C_junction_2_0': 3, 'end_C_junction_2_1': 0, 'end_D_junction_2_0': 1, 'end_D_junction_2_1': 0, 'junction_3_junction_2_0': 0, 'junction_3_junction_2_1': 0, 'junction_1_junction_2_0': 0, 'junction_1_junction_2_1': 0}, 'lane_speed': {'end_C_junction_2_0': 13.417349933700205, 'end_C_junction_2_1': 0.0, 'end_D_junction_2_0': 6.615182348246418, 'end_D_junction_2_1': 0.0, 'junction_3_junction_2_0': 0.0, 'junction_3_junction_2_1': 0.0, 'junction_1_junction_2_0': 0.0, 'junction_1_junction_2_1': 0.0}}, 'junction_3': {'all_phases': {"(Logic(programID='0', type=0, currentPhaseIndex=0, phases=(Phase(duration=29.0, state='rrrrGGGGgrrrrGGGGg', minDur=29.0, maxDur=29.0), Phase(duration=16.0, state='rrrryyyyyrrrryyyyy', minDur=16.0, maxDur=16.0), Phase(duration=29.0, state='GGGgrrrrrGGGgrrrrr', minDur=29.0, maxDur=29.0), Phase(duration=16.0, state='yyyyrrrrryyyyrrrrr', minDur=16.0, maxDur=16.0)), subParameter={}),)"}, 'current_phase': {0}, 'nb_lanes': 18, 'lanes_list': ('junction_2_junction_3_0', 'junction_2_junction_3_0', 'junction_2_junction_3_1', 'junction_2_junction_3_1', 'end_E_junction_3_0', 'end_E_junction_3_0', 'end_E_junction_3_1', 'end_E_junction_3_2', 'end_E_junction_3_2', 'junction_4_junction_3_0', 'junction_4_junction_3_0', 'junction_4_junction_3_1', 'junction_4_junction_3_1', 'junction_6_junction_3_0', 'junction_6_junction_3_0', 'junction_6_junction_3_1', 'junction_6_junction_3_2', 'junction_6_junction_3_2'), 'lane_halting': {'junction_2_junction_3_0': 0, 'junction_2_junction_3_1': 0, 'end_E_junction_3_0': 0, 'end_E_junction_3_1': 0, 'end_E_junction_3_2': 0, 'junction_4_junction_3_0': 0, 'junction_4_junction_3_1': 0, 'junction_6_junction_3_0': 0, 'junction_6_junction_3_1': 0, 'junction_6_junction_3_2': 0}, 'passenger_halting': {'junction_2_junction_3_0': 0.0, 'junction_2_junction_3_1': 0.0, 'end_E_junction_3_0': 0.0, 'end_E_junction_3_1': 0.0, 'end_E_junction_3_2': 0.0, 'junction_4_junction_3_0': 0.0, 'junction_4_junction_3_1': 0.0, 'junction_6_junction_3_0': 0.0, 'junction_6_junction_3_1': 0.0, 'junction_6_junction_3_2': 0.0}, 'passenger_wait_time': {'junction_2_junction_3_0': 0.0, 'junction_2_junction_3_1': 0.0, 'end_E_junction_3_0': 0.0, 'end_E_junction_3_1': 0.0, 'end_E_junction_3_2': 0.0, 'junction_4_junction_3_0': 0.0, 'junction_4_junction_3_1': 0.0, 'junction_6_junction_3_0': 0.0, 'junction_6_junction_3_1': 0.0, 'junction_6_junction_3_2': 0.0}, 'lane_occupency': {'junction_2_junction_3_0': 0, 'junction_2_junction_3_1': 0, 'end_E_junction_3_0': 3, 'end_E_junction_3_1': 1, 'end_E_junction_3_2': 0, 'junction_4_junction_3_0': 0, 'junction_4_junction_3_1': 0, 'junction_6_junction_3_0': 0, 'junction_6_junction_3_1': 0, 'junction_6_junction_3_2': 0}, 'lane_speed': {'junction_2_junction_3_0': 0.0, 'junction_2_junction_3_1': 0.0, 'end_E_junction_3_0': 8.690260008497015, 'end_E_junction_3_1': 4.875448886058414, 'end_E_junction_3_2': 0.0, 'junction_4_junction_3_0': 0.0, 'junction_4_junction_3_1': 0.0, 'junction_6_junction_3_0': 0.0, 'junction_6_junction_3_1': 0.0, 'junction_6_junction_3_2': 0.0}}, 'junction_4': {'all_phases': {"(Logic(programID='0', type=0, currentPhaseIndex=0, phases=(Phase(duration=35.0, state='GGGgrrrrGGGgrrrr', minDur=35.0, maxDur=35.0), Phase(duration=10.0, state='yyyyrrrryyyyrrrr', minDur=10.0, maxDur=10.0), Phase(duration=35.0, state='rrrrGGGgrrrrGGGg', minDur=35.0, maxDur=35.0), Phase(duration=10.0, state='rrrryyyyrrrryyyy', minDur=10.0, maxDur=10.0)), subParameter={}),)"}, 'current_phase': {0}, 'nb_lanes': 16, 'lanes_list': ('junction_3_junction_4_0', 'junction_3_junction_4_0', 'junction_3_junction_4_1', 'junction_3_junction_4_1', 'end_F_junction_4_0', 'end_F_junction_4_0', 'end_F_junction_4_1', 'end_F_junction_4_1', 'end_G_junction_4_0', 'end_G_junction_4_0', 'end_G_junction_4_1', 'end_G_junction_4_1', 'junction_5_junction_4_0', 'junction_5_junction_4_0', 'junction_5_junction_4_1', 'junction_5_junction_4_1'), 'lane_halting': {'junction_3_junction_4_0': 0, 'junction_3_junction_4_1': 0, 'end_F_junction_4_0': 0, 'end_F_junction_4_1': 0, 'end_G_junction_4_0': 0, 'end_G_junction_4_1': 0, 'junction_5_junction_4_0': 0, 'junction_5_junction_4_1': 0}, 'passenger_halting': {'junction_3_junction_4_0': 0.0, 'junction_3_junction_4_1': 0.0, 'end_F_junction_4_0': 0.0, 'end_F_junction_4_1': 0.0, 'end_G_junction_4_0': 0.0, 'end_G_junction_4_1': 0.0, 'junction_5_junction_4_0': 0.0, 'junction_5_junction_4_1': 0.0}, 'passenger_wait_time': {'junction_3_junction_4_0': 0.0, 'junction_3_junction_4_1': 0.0, 'end_F_junction_4_0': 0.0, 'end_F_junction_4_1': 0.0, 'end_G_junction_4_0': 0.0, 'end_G_junction_4_1': 0.0, 'junction_5_junction_4_0': 0.0, 'junction_5_junction_4_1': 0.0}, 'lane_occupency': {'junction_3_junction_4_0': 0, 'junction_3_junction_4_1': 0, 'end_F_junction_4_0': 2, 'end_F_junction_4_1': 0, 'end_G_junction_4_0': 0, 'end_G_junction_4_1': 0, 'junction_5_junction_4_0': 0, 'junction_5_junction_4_1': 0}, 'lane_speed': {'junction_3_junction_4_0': 0.0, 'junction_3_junction_4_1': 0.0, 'end_F_junction_4_0': 18.23064662253283, 'end_F_junction_4_1': 0.0, 'end_G_junction_4_0': 0.0, 'end_G_junction_4_1': 0.0, 'junction_5_junction_4_0': 0.0, 'junction_5_junction_4_1': 0.0}}, 'junction_5': {'all_phases': {"(Logic(programID='0', type=0, currentPhaseIndex=0, phases=(Phase(duration=35.0, state='GGGgrrrrGGGgrrrr', minDur=35.0, maxDur=35.0), Phase(duration=10.0, state='yyyyrrrryyyyrrrr', minDur=10.0, maxDur=10.0), Phase(duration=35.0, state='rrrrGGGgrrrrGGGg', minDur=35.0, maxDur=35.0), Phase(duration=10.0, state='rrrryyyyrrrryyyy', minDur=10.0, maxDur=10.0)), subParameter={}),)"}, 'current_phase': {0}, 'nb_lanes': 16, 'lanes_list': ('junction_6_junction_5_0', 'junction_6_junction_5_0', 'junction_6_junction_5_1', 'junction_6_junction_5_1', 'junction_4_junction_5_0', 'junction_4_junction_5_0', 'junction_4_junction_5_1', 'junction_4_junction_5_1', 'end_H_junction_5_0', 'end_H_junction_5_0', 'end_H_junction_5_1', 'end_H_junction_5_1', 'end_I_junction_5_0', 'end_I_junction_5_0', 'end_I_junction_5_1', 'end_I_junction_5_1'), 'lane_halting': {'junction_6_junction_5_0': 0, 'junction_6_junction_5_1': 0, 'junction_4_junction_5_0': 0, 'junction_4_junction_5_1': 0, 'end_H_junction_5_0': 0, 'end_H_junction_5_1': 0, 'end_I_junction_5_0': 0, 'end_I_junction_5_1': 0}, 'passenger_halting': {'junction_6_junction_5_0': 0.0, 'junction_6_junction_5_1': 0.0, 'junction_4_junction_5_0': 0.0, 'junction_4_junction_5_1': 0.0, 'end_H_junction_5_0': 0.0, 'end_H_junction_5_1': 0.0, 'end_I_junction_5_0': 0.0, 'end_I_junction_5_1': 0.0}, 'passenger_wait_time': {'junction_6_junction_5_0': 0.0, 'junction_6_junction_5_1': 0.0, 'junction_4_junction_5_0': 0.0, 'junction_4_junction_5_1': 0.0, 'end_H_junction_5_0': 0.0, 'end_H_junction_5_1': 0.0, 'end_I_junction_5_0': 0.0, 'end_I_junction_5_1': 0.0}, 'lane_occupency': {'junction_6_junction_5_0': 0, 'junction_6_junction_5_1': 0, 'junction_4_junction_5_0': 0, 'junction_4_junction_5_1': 0, 'end_H_junction_5_0': 2, 'end_H_junction_5_1': 2, 'end_I_junction_5_0': 2, 'end_I_junction_5_1': 0}, 'lane_speed': {'junction_6_junction_5_0': 0.0, 'junction_6_junction_5_1': 0.0, 'junction_4_junction_5_0': 0.0, 'junction_4_junction_5_1': 0.0, 'end_H_junction_5_0': 5.303182013514008, 'end_H_junction_5_1': 32.33685583815196, 'end_I_junction_5_0': 10.12300436533114, 'end_I_junction_5_1': 0.0}}, 'junction_6': {'all_phases': {"(Logic(programID='0', type=0, currentPhaseIndex=0, phases=(Phase(duration=29.0, state='rrrrGGGGgrrrrGGGGg', minDur=29.0, maxDur=29.0), Phase(duration=16.0, state='rrrryyyyyrrrryyyyy', minDur=16.0, maxDur=16.0), Phase(duration=29.0, state='GGGgrrrrrGGGgrrrrr', minDur=29.0, maxDur=29.0), Phase(duration=16.0, state='yyyyrrrrryyyyrrrrr', minDur=16.0, maxDur=16.0), Phase(duration=2.0, state='grrrgrrrggrrrgrrrg', minDur=2.0, maxDur=2.0)), subParameter={}),)"}, 'current_phase': {0}, 'nb_lanes': 18, 'lanes_list': ('junction_1_junction_6_0', 'junction_1_junction_6_0', 'junction_1_junction_6_1', 'junction_1_junction_6_1', 'junction_3_junction_6_0', 'junction_3_junction_6_0', 'junction_3_junction_6_1', 'junction_3_junction_6_2', 'junction_3_junction_6_2', 'junction_5_junction_6_0', 'junction_5_junction_6_0', 'junction_5_junction_6_1', 'junction_5_junction_6_1', 'end_J_junction_6_0', 'end_J_junction_6_0', 'end_J_junction_6_1', 'end_J_junction_6_2', 'end_J_junction_6_2'), 'lane_halting': {'junction_1_junction_6_0': 0, 'junction_1_junction_6_1': 0, 'junction_3_junction_6_0': 0, 'junction_3_junction_6_1': 0, 'junction_3_junction_6_2': 0, 'junction_5_junction_6_0': 0, 'junction_5_junction_6_1': 0, 'end_J_junction_6_0': 0, 'end_J_junction_6_1': 0, 'end_J_junction_6_2': 0}, 'passenger_halting': {'junction_1_junction_6_0': 0.0, 'junction_1_junction_6_1': 0.0, 'junction_3_junction_6_0': 0.0, 'junction_3_junction_6_1': 0.0, 'junction_3_junction_6_2': 0.0, 'junction_5_junction_6_0': 0.0, 'junction_5_junction_6_1': 0.0, 'end_J_junction_6_0': 0.0, 'end_J_junction_6_1': 0.0, 'end_J_junction_6_2': 0.0}, 'passenger_wait_time': {'junction_1_junction_6_0': 0.0, 'junction_1_junction_6_1': 0.0, 'junction_3_junction_6_0': 0.0, 'junction_3_junction_6_1': 0.0, 'junction_3_junction_6_2': 0.0, 'junction_5_junction_6_0': 0.0, 'junction_5_junction_6_1': 0.0, 'end_J_junction_6_0': 0.0, 'end_J_junction_6_1': 0.0, 'end_J_junction_6_2': 0.0}, 'lane_occupency': {'junction_1_junction_6_0': 0, 'junction_1_junction_6_1': 0, 'junction_3_junction_6_0': 0, 'junction_3_junction_6_1': 0, 'junction_3_junction_6_2': 0, 'junction_5_junction_6_0': 0, 'junction_5_junction_6_1': 0, 'end_J_junction_6_0': 2, 'end_J_junction_6_1': 1, 'end_J_junction_6_2': 0}, 'lane_speed': {'junction_1_junction_6_0': 0.0, 'junction_1_junction_6_1': 0.0, 'junction_3_junction_6_0': 0.0, 'junction_3_junction_6_1': 0.0, 'junction_3_junction_6_2': 0.0, 'junction_5_junction_6_0': 0.0, 'junction_5_junction_6_1': 0.0, 'end_J_junction_6_0': 7.1334659874206245, 'end_J_junction_6_1': 3.222367052871691, 'end_J_junction_6_2': 0.0}}}

# %%
df = pd.DataFrame.from_dict(dict)
df
# Out:
#                                                             junction_1  \
# all_phases           {(Logic(programID='0', type=0, currentPhaseInd...
# current_phase                                                      {0}
# nb_lanes                                                            16
# lanes_list           (end_B_junction_1_0, end_B_junction_1_0, end_B...
# lane_halting         {'end_B_junction_1_0': 0, 'end_B_junction_1_1'...
# passenger_halting    {'end_B_junction_1_0': 0.0, 'end_B_junction_1_...
# passenger_wait_time  {'end_B_junction_1_0': 0.0, 'end_B_junction_1_...
# lane_occupency       {'end_B_junction_1_0': 0, 'end_B_junction_1_1'...
# lane_speed           {'end_B_junction_1_0': 0.0, 'end_B_junction_1_...
#
#                                                             junction_2  \
# all_phases           {(Logic(programID='0', type=0, currentPhaseInd...
# current_phase                                                      {0}
# ...

# %%
import json

json_data = json.dumps(dict)
json_data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 import json
# ----> 3 json_data = json.dumps(dict)
#       4 json_data
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/json/__init__.py:231, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     226 # cached encoder
#     227 if (not skipkeys and ensure_ascii and
#     228     check_circular and allow_nan and
#     229     cls is None and indent is None and separators is None and
#     230     default is None and not sort_keys and not kw):
# --> 231     return _default_encoder.encode(obj)
#     232 if cls is None:
#     233     cls = JSONEncoder
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/json/encoder.py:199, in JSONEncoder.encode(self, o)
#     195         return encode_basestring(o)
# ...

# %%
import json

# Your dictionary (truncated for brevity)
data = {
    "junction_1": {
        "all_phases": {"(Logic(programID='0', type=0, currentPhaseIndex=0, phases=(Phase(duration=35.0, state='GGGgrrrrGGGgrrrr', minDur=35.0, maxDur=35.0), Phase(duration=10.0, state='yyyyrrrryyyyrrrr', minDur=10.0, maxDur=10.0), Phase(duration=35.0, state='rrrrGGGgrrrrGGGg', minDur=35.0, maxDur=35.0), Phase(duration=10.0, state='rrrryyyyrrrryyyy', minDur=10.0, maxDur=10.0)), subParameter={}),)"},
        "current_phase": {0},
        "nb_lanes": 16,
        "lanes_list": (
            "end_B_junction_1_0",
            "end_B_junction_1_0",
            "end_B_junction_1_1",
            "end_B_junction_1_1",
            "junction_2_junction_1_0",
            "junction_2_junction_1_0",
            "junction_2_junction_1_1",
            "junction_2_junction_1_1",
        ),
        "lane_halting": {"end_B_junction_1_0": 0, "end_B_junction_1_1": 0},
        "passenger_halting": {"end_B_junction_1_0": 0.0, "end_B_junction_1_1": 0.0},
    }
}

# Convert to JSON
json_data = json.dumps(data, indent=4)

# Print or save the JSON output
print(json_data)

# If you want to save it to a file:
with open("traffic_data.json", "w") as f:
    json.dump(data, f, indent=4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 25
#       4 data = {
#       5     "junction_1": {
#       6         "all_phases": {"(Logic(programID='0', type=0, currentPhaseIndex=0, phases=(Phase(duration=35.0, state='GGGgrrrrGGGgrrrr', minDur=35.0, maxDur=35.0), Phase(duration=10.0, state='yyyyrrrryyyyrrrr', minDur=10.0, maxDur=10.0), Phase(duration=35.0, state='rrrrGGGgrrrrGGGg', minDur=35.0, maxDur=35.0), Phase(duration=10.0, state='rrrryyyyrrrryyyy', minDur=10.0, maxDur=10.0)), subParameter={}),)"},
#    (...)
#      21     }
#      22 }
#      24 # Convert to JSON
# ---> 25 json_data = json.dumps(data, indent=4)
#      27 # Print or save the JSON output
#      28 print(json_data)
#
# ...
